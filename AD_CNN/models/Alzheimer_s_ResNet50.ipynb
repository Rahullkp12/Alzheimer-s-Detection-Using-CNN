# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

#import tensorflow_addons as tfa
#from tensorflow.keras.metrics import Metric
#from tensorflow_addons.utils.types import AcceptableDTypes, FloatTensorLike
from typeguard import typechecked
from typing import Optional

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Alzheimer_s Dataset/test',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 32)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
base_model = ResNet50(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
def get_transfer_block(base_model, weights = 'imagenet', img_size = 246, unfrezz_some_layer=True, trainable = 5):
  """
  Description: Prepares a transfer learning block from keras\n
  Parameters:
  \t tranfer_learning_model: keras transfer learning block
  \t weights = pretrained weights to use
  \t img_size = the size of the training image
  \t unfrezz_some_layer = make some layers from transfer model trainable
  \t trainable = if unfreez is true how many layer are trainble on the tranfer model
  """
  ### reading in the tranfer learning model
  base_model = base_model(
      include_top=False,
      weights= weights,
      input_shape=(img_size, img_size, 3),

  )
  ### For Setting the number of trainable parameter
  for layer in base_model.layers:
      layer.trainable = False

  if unfrezz_some_layers == unfrezz_some_layer:
      trainable = trainable_layers
      for i in range(-trainable, 0):
        base_model.layers[i].trainable = True
  return base_model

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(4,activation='softmax'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  batch_normalization (BatchN  (None, 100352)           401408
#  ormalization)
#
#  dense (Dense)               (None, 64)                6422592
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation (Activation)     (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 30,424,324
# Trainable params: 30,169,988
# Non-trainable params: 254,336
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 50,
                        verbose = 1,
                        callbacks=lr_scheduler)
# Out:
# Epoch 1/50
# 129/129 [==============================] - 1356s 10s/step - loss: 1.0704 - accuracy: 0.7565 - precision: 0.5338 - recall: 0.2040 - auc: 0.7755 - f1_score: 0.2849 - val_loss: 129462512.0000 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.6670 - val_f1_score: 0.5005 - lr: 0.0100
# Epoch 2/50
# 129/129 [==============================] - 106s 820ms/step - loss: 1.0281 - accuracy: 0.7670 - precision: 0.6144 - recall: 0.1828 - auc: 0.7933 - f1_score: 0.2779 - val_loss: 1.0391 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7804 - val_f1_score: 0.0000e+00 - lr: 0.0063
# Epoch 3/50
# 129/129 [==============================] - 106s 819ms/step - loss: 0.9867 - accuracy: 0.7815 - precision: 0.7622 - recall: 0.1830 - auc: 0.8047 - f1_score: 0.2943 - val_loss: 1.0610 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7553 - val_f1_score: 0.0000e+00 - lr: 0.0040
# Epoch 4/50
# 129/129 [==============================] - 106s 821ms/step - loss: 0.9631 - accuracy: 0.7903 - precision: 0.7455 - recall: 0.2445 - auc: 0.8180 - f1_score: 0.3693 - val_loss: 1.0059 - val_accuracy: 0.7937 - val_precision: 0.6861 - val_recall: 0.3226 - val_auc: 0.8248 - val_f1_score: 0.4364 - lr: 0.0025
# Epoch 5/50
# 129/129 [==============================] - 107s 824ms/step - loss: 0.9323 - accuracy: 0.7946 - precision: 0.7519 - recall: 0.2662 - auc: 0.8283 - f1_score: 0.3943 - val_loss: 0.9061 - val_accuracy: 0.8062 - val_precision: 0.7246 - val_recall: 0.3627 - val_auc: 0.8427 - val_f1_score: 0.4805 - lr: 0.0016
# Epoch 6/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.9268 - accuracy: 0.7978 - precision: 0.7552 - recall: 0.2831 - auc: 0.8325 - f1_score: 0.4114 - val_loss: 1.1285 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7346 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 7/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.9160 - accuracy: 0.7976 - precision: 0.7539 - recall: 0.2826 - auc: 0.8354 - f1_score: 0.4108 - val_loss: 1.1134 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7549 - val_f1_score: 0.0000e+00 - lr: 6.3096e-04
# Epoch 8/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8987 - accuracy: 0.8010 - precision: 0.7616 - recall: 0.2970 - auc: 0.8409 - f1_score: 0.4229 - val_loss: 0.9433 - val_accuracy: 0.7981 - val_precision: 0.6667 - val_recall: 0.3851 - val_auc: 0.8424 - val_f1_score: 0.4859 - lr: 3.9811e-04
# Epoch 9/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.9056 - accuracy: 0.8006 - precision: 0.7623 - recall: 0.2943 - auc: 0.8366 - f1_score: 0.4258 - val_loss: 0.9119 - val_accuracy: 0.8018 - val_precision: 0.8487 - val_recall: 0.2522 - val_auc: 0.8416 - val_f1_score: 0.3823 - lr: 2.5119e-04
# Epoch 10/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8973 - accuracy: 0.8005 - precision: 0.7602 - recall: 0.2948 - auc: 0.8393 - f1_score: 0.4258 - val_loss: 1.0511 - val_accuracy: 0.7617 - val_precision: 1.0000 - val_recall: 0.0469 - val_auc: 0.7838 - val_f1_score: 0.0866 - lr: 1.5849e-04
# Epoch 11/50
# 129/129 [==============================] - 107s 824ms/step - loss: 0.8897 - accuracy: 0.8041 - precision: 0.7711 - recall: 0.3075 - auc: 0.8442 - f1_score: 0.4393 - val_loss: 0.9364 - val_accuracy: 0.7957 - val_precision: 0.8848 - val_recall: 0.2102 - val_auc: 0.8324 - val_f1_score: 0.3334 - lr: 1.0000e-04
# Epoch 12/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.9027 - accuracy: 0.7995 - precision: 0.7476 - recall: 0.2992 - auc: 0.8369 - f1_score: 0.4274 - val_loss: 0.9678 - val_accuracy: 0.7871 - val_precision: 0.9578 - val_recall: 0.1554 - val_auc: 0.8237 - val_f1_score: 0.2621 - lr: 6.3096e-05
# Epoch 13/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8909 - accuracy: 0.8020 - precision: 0.7656 - recall: 0.2997 - auc: 0.8412 - f1_score: 0.4307 - val_loss: 0.9562 - val_accuracy: 0.7908 - val_precision: 0.9196 - val_recall: 0.1789 - val_auc: 0.8269 - val_f1_score: 0.2934 - lr: 3.9811e-05
# Epoch 14/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8923 - accuracy: 0.8008 - precision: 0.7541 - recall: 0.3016 - auc: 0.8399 - f1_score: 0.4317 - val_loss: 0.9607 - val_accuracy: 0.7908 - val_precision: 0.9239 - val_recall: 0.1779 - val_auc: 0.8249 - val_f1_score: 0.2941 - lr: 2.5119e-05
# Epoch 15/50
# 129/129 [==============================] - 107s 824ms/step - loss: 0.8930 - accuracy: 0.8023 - precision: 0.7668 - recall: 0.3009 - auc: 0.8410 - f1_score: 0.4320 - val_loss: 0.9531 - val_accuracy: 0.7920 - val_precision: 0.9216 - val_recall: 0.1838 - val_auc: 0.8252 - val_f1_score: 0.2996 - lr: 1.5849e-05
# Epoch 16/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8996 - accuracy: 0.8034 - precision: 0.7679 - recall: 0.3060 - auc: 0.8429 - f1_score: 0.4374 - val_loss: 0.9378 - val_accuracy: 0.7950 - val_precision: 0.8932 - val_recall: 0.2043 - val_auc: 0.8319 - val_f1_score: 0.3258 - lr: 1.0000e-05
# Epoch 17/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8892 - accuracy: 0.8024 - precision: 0.7598 - recall: 0.3065 - auc: 0.8434 - f1_score: 0.4329 - val_loss: 0.9528 - val_accuracy: 0.7933 - val_precision: 0.9234 - val_recall: 0.1887 - val_auc: 0.8275 - val_f1_score: 0.3055 - lr: 6.3096e-06
# Epoch 18/50
# 129/129 [==============================] - 107s 822ms/step - loss: 0.8998 - accuracy: 0.8011 - precision: 0.7564 - recall: 0.3016 - auc: 0.8394 - f1_score: 0.4324 - val_loss: 0.9464 - val_accuracy: 0.7930 - val_precision: 0.9000 - val_recall: 0.1935 - val_auc: 0.8263 - val_f1_score: 0.3148 - lr: 3.9811e-06
# Epoch 19/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8900 - accuracy: 0.8025 - precision: 0.7627 - recall: 0.3050 - auc: 0.8418 - f1_score: 0.4353 - val_loss: 0.9487 - val_accuracy: 0.7935 - val_precision: 0.9083 - val_recall: 0.1935 - val_auc: 0.8291 - val_f1_score: 0.3140 - lr: 2.5119e-06
# Epoch 20/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8939 - accuracy: 0.8026 - precision: 0.7628 - recall: 0.3053 - auc: 0.8412 - f1_score: 0.4360 - val_loss: 0.9453 - val_accuracy: 0.7937 - val_precision: 0.8978 - val_recall: 0.1975 - val_auc: 0.8292 - val_f1_score: 0.3189 - lr: 1.5849e-06
# Epoch 21/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8966 - accuracy: 0.8015 - precision: 0.7608 - recall: 0.3004 - auc: 0.8402 - f1_score: 0.4312 - val_loss: 0.9415 - val_accuracy: 0.7945 - val_precision: 0.8922 - val_recall: 0.2023 - val_auc: 0.8287 - val_f1_score: 0.3256 - lr: 1.0000e-06
# Epoch 22/50
# 129/129 [==============================] - 107s 824ms/step - loss: 0.8919 - accuracy: 0.8013 - precision: 0.7553 - recall: 0.3036 - auc: 0.8418 - f1_score: 0.4326 - val_loss: 0.9466 - val_accuracy: 0.7920 - val_precision: 0.8945 - val_recall: 0.1906 - val_auc: 0.8267 - val_f1_score: 0.3096 - lr: 6.3096e-07
# Epoch 23/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8976 - accuracy: 0.8008 - precision: 0.7558 - recall: 0.2999 - auc: 0.8390 - f1_score: 0.4257 - val_loss: 0.9455 - val_accuracy: 0.7923 - val_precision: 0.9023 - val_recall: 0.1896 - val_auc: 0.8290 - val_f1_score: 0.3100 - lr: 3.9811e-07
# Epoch 24/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8864 - accuracy: 0.8036 - precision: 0.7710 - recall: 0.3048 - auc: 0.8442 - f1_score: 0.4363 - val_loss: 0.9460 - val_accuracy: 0.7930 - val_precision: 0.9000 - val_recall: 0.1935 - val_auc: 0.8296 - val_f1_score: 0.3153 - lr: 2.5119e-07
# Epoch 25/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8919 - accuracy: 0.8025 - precision: 0.7627 - recall: 0.3050 - auc: 0.8425 - f1_score: 0.4392 - val_loss: 0.9472 - val_accuracy: 0.7935 - val_precision: 0.9279 - val_recall: 0.1887 - val_auc: 0.8296 - val_f1_score: 0.3111 - lr: 1.5849e-07
# Epoch 26/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8915 - accuracy: 0.8032 - precision: 0.7691 - recall: 0.3041 - auc: 0.8423 - f1_score: 0.4353 - val_loss: 0.9458 - val_accuracy: 0.7933 - val_precision: 0.9005 - val_recall: 0.1945 - val_auc: 0.8260 - val_f1_score: 0.3148 - lr: 1.0000e-07
# Epoch 27/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8953 - accuracy: 0.8015 - precision: 0.7570 - recall: 0.3033 - auc: 0.8401 - f1_score: 0.4328 - val_loss: 0.9452 - val_accuracy: 0.7935 - val_precision: 0.9045 - val_recall: 0.1945 - val_auc: 0.8293 - val_f1_score: 0.3147 - lr: 6.3096e-08
# Epoch 28/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8863 - accuracy: 0.8011 - precision: 0.7591 - recall: 0.2992 - auc: 0.8431 - f1_score: 0.4323 - val_loss: 0.9476 - val_accuracy: 0.7942 - val_precision: 0.9209 - val_recall: 0.1935 - val_auc: 0.8283 - val_f1_score: 0.3149 - lr: 3.9811e-08
# Epoch 29/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8984 - accuracy: 0.8014 - precision: 0.7542 - recall: 0.3048 - auc: 0.8400 - f1_score: 0.4335 - val_loss: 0.9482 - val_accuracy: 0.7933 - val_precision: 0.9005 - val_recall: 0.1945 - val_auc: 0.8286 - val_f1_score: 0.3157 - lr: 2.5119e-08
# Epoch 30/50
# 129/129 [==============================] - 106s 823ms/step - loss: 0.8959 - accuracy: 0.7999 - precision: 0.7509 - recall: 0.2987 - auc: 0.8409 - f1_score: 0.4237 - val_loss: 0.9461 - val_accuracy: 0.7930 - val_precision: 0.9000 - val_recall: 0.1935 - val_auc: 0.8277 - val_f1_score: 0.3131 - lr: 1.5849e-08
# Epoch 31/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8961 - accuracy: 0.8005 - precision: 0.7521 - recall: 0.3014 - auc: 0.8410 - f1_score: 0.4264 - val_loss: 0.9458 - val_accuracy: 0.7928 - val_precision: 0.8889 - val_recall: 0.1955 - val_auc: 0.8266 - val_f1_score: 0.3145 - lr: 1.0000e-08
# Epoch 32/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8879 - accuracy: 0.8026 - precision: 0.7631 - recall: 0.3050 - auc: 0.8434 - f1_score: 0.4367 - val_loss: 0.9451 - val_accuracy: 0.7942 - val_precision: 0.8952 - val_recall: 0.2004 - val_auc: 0.8255 - val_f1_score: 0.3221 - lr: 6.3096e-09
# Epoch 33/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8903 - accuracy: 0.8012 - precision: 0.7575 - recall: 0.3011 - auc: 0.8420 - f1_score: 0.4306 - val_loss: 0.9465 - val_accuracy: 0.7937 - val_precision: 0.9087 - val_recall: 0.1945 - val_auc: 0.8261 - val_f1_score: 0.3164 - lr: 3.9811e-09
# Epoch 34/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8921 - accuracy: 0.8014 - precision: 0.7626 - recall: 0.2987 - auc: 0.8413 - f1_score: 0.4250 - val_loss: 0.9461 - val_accuracy: 0.7925 - val_precision: 0.9104 - val_recall: 0.1887 - val_auc: 0.8270 - val_f1_score: 0.3083 - lr: 2.5119e-09
# Epoch 35/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8955 - accuracy: 0.8000 - precision: 0.7485 - recall: 0.3014 - auc: 0.8402 - f1_score: 0.4307 - val_loss: 0.9476 - val_accuracy: 0.7940 - val_precision: 0.9245 - val_recall: 0.1916 - val_auc: 0.8252 - val_f1_score: 0.3128 - lr: 1.5849e-09
# Epoch 36/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8888 - accuracy: 0.8024 - precision: 0.7659 - recall: 0.3019 - auc: 0.8416 - f1_score: 0.4340 - val_loss: 0.9454 - val_accuracy: 0.7935 - val_precision: 0.9009 - val_recall: 0.1955 - val_auc: 0.8275 - val_f1_score: 0.3177 - lr: 1.0000e-09
# Epoch 37/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8926 - accuracy: 0.8017 - precision: 0.7634 - recall: 0.2999 - auc: 0.8419 - f1_score: 0.4301 - val_loss: 0.9481 - val_accuracy: 0.7925 - val_precision: 0.9065 - val_recall: 0.1896 - val_auc: 0.8292 - val_f1_score: 0.3090 - lr: 6.3096e-10
# Epoch 38/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8924 - accuracy: 0.8026 - precision: 0.7600 - recall: 0.3075 - auc: 0.8428 - f1_score: 0.4385 - val_loss: 0.9449 - val_accuracy: 0.7933 - val_precision: 0.9005 - val_recall: 0.1945 - val_auc: 0.8282 - val_f1_score: 0.3160 - lr: 3.9811e-10
# Epoch 39/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8947 - accuracy: 0.8008 - precision: 0.7538 - recall: 0.3019 - auc: 0.8415 - f1_score: 0.4305 - val_loss: 0.9455 - val_accuracy: 0.7935 - val_precision: 0.9045 - val_recall: 0.1945 - val_auc: 0.8270 - val_f1_score: 0.3130 - lr: 2.5119e-10
# Epoch 40/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8953 - accuracy: 0.8013 - precision: 0.7588 - recall: 0.3009 - auc: 0.8391 - f1_score: 0.4319 - val_loss: 0.9430 - val_accuracy: 0.7935 - val_precision: 0.8904 - val_recall: 0.1984 - val_auc: 0.8284 - val_f1_score: 0.3190 - lr: 1.5849e-10
# Epoch 41/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8934 - accuracy: 0.8017 - precision: 0.7562 - recall: 0.3050 - auc: 0.8419 - f1_score: 0.4308 - val_loss: 0.9400 - val_accuracy: 0.7940 - val_precision: 0.8913 - val_recall: 0.2004 - val_auc: 0.8268 - val_f1_score: 0.3229 - lr: 1.0000e-10
# Epoch 42/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8891 - accuracy: 0.8031 - precision: 0.7665 - recall: 0.3053 - auc: 0.8441 - f1_score: 0.4399 - val_loss: 0.9426 - val_accuracy: 0.7937 - val_precision: 0.8908 - val_recall: 0.1994 - val_auc: 0.8271 - val_f1_score: 0.3195 - lr: 6.3096e-11
# Epoch 43/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8952 - accuracy: 0.8017 - precision: 0.7592 - recall: 0.3031 - auc: 0.8421 - f1_score: 0.4325 - val_loss: 0.9431 - val_accuracy: 0.7933 - val_precision: 0.8899 - val_recall: 0.1975 - val_auc: 0.8274 - val_f1_score: 0.3169 - lr: 3.9811e-11
# Epoch 44/50
# 129/129 [==============================] - 106s 823ms/step - loss: 0.8926 - accuracy: 0.8018 - precision: 0.7587 - recall: 0.3038 - auc: 0.8416 - f1_score: 0.4300 - val_loss: 0.9437 - val_accuracy: 0.7937 - val_precision: 0.8908 - val_recall: 0.1994 - val_auc: 0.8278 - val_f1_score: 0.3204 - lr: 2.5119e-11
# Epoch 45/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8967 - accuracy: 0.8028 - precision: 0.7650 - recall: 0.3050 - auc: 0.8412 - f1_score: 0.4396 - val_loss: 0.9464 - val_accuracy: 0.7937 - val_precision: 0.9013 - val_recall: 0.1965 - val_auc: 0.8262 - val_f1_score: 0.3172 - lr: 1.5849e-11
# Epoch 46/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8984 - accuracy: 0.8009 - precision: 0.7535 - recall: 0.3028 - auc: 0.8398 - f1_score: 0.4351 - val_loss: 0.9456 - val_accuracy: 0.7935 - val_precision: 0.9120 - val_recall: 0.1926 - val_auc: 0.8258 - val_f1_score: 0.3125 - lr: 1.0000e-11
# Epoch 47/50
# 129/129 [==============================] - 106s 823ms/step - loss: 0.8899 - accuracy: 0.8013 - precision: 0.7594 - recall: 0.3004 - auc: 0.8421 - f1_score: 0.4301 - val_loss: 0.9419 - val_accuracy: 0.7940 - val_precision: 0.8913 - val_recall: 0.2004 - val_auc: 0.8309 - val_f1_score: 0.3229 - lr: 6.3096e-12
# Epoch 48/50
# 129/129 [==============================] - 107s 823ms/step - loss: 0.8981 - accuracy: 0.8016 - precision: 0.7579 - recall: 0.3033 - auc: 0.8409 - f1_score: 0.4324 - val_loss: 0.9467 - val_accuracy: 0.7925 - val_precision: 0.9028 - val_recall: 0.1906 - val_auc: 0.8309 - val_f1_score: 0.3100 - lr: 3.9811e-12
# Epoch 49/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8943 - accuracy: 0.8026 - precision: 0.7626 - recall: 0.3058 - auc: 0.8419 - f1_score: 0.4373 - val_loss: 0.9449 - val_accuracy: 0.7935 - val_precision: 0.8938 - val_recall: 0.1975 - val_auc: 0.8336 - val_f1_score: 0.3156 - lr: 2.5119e-12
# Epoch 50/50
# 129/129 [==============================] - 106s 822ms/step - loss: 0.8995 - accuracy: 0.7998 - precision: 0.7492 - recall: 0.2997 - auc: 0.8388 - f1_score: 0.4244 - val_loss: 0.9432 - val_accuracy: 0.7930 - val_precision: 0.8894 - val_recall: 0.1965 - val_auc: 0.8274 - val_f1_score: 0.3169 - lr: 1.5849e-12

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate_generator(test_dataset)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.7996481657028198
# Precision =  0.7343173623085022
# Recall =  0.31118062138557434
# AUC =  0.8420288562774658
# F1_score =  0.4327986240386963
